# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
data = np.linspace(0.0,10.0,1000000)

# %%
noise = np.random.randn(len(data))

# %% [markdown]
# y = m * x + c
#
# c=5
# m=0.5

# %%
y_exp = (0.5 * data) + 5 + noise

# %%
feature = pd.DataFrame(data,columns=['feature'])

# %%
label = pd.DataFrame(y_exp,columns=['Label'])

# %%
dataset = pd.concat([feature,label],axis=1)

# %%
dataset.sample(300).plot(x='feature',y='Label',kind='scatter')

# %% [markdown]
# ### TF trial

# %%
batch_size = 10

# %%
np.random.random(2)
# Out:
# array([0.62706073, 0.67761975])

# %%
#Variables are mutable
m = tf.Variable(0.62)
c = tf.Variable(0.67)
#placeholders are immutable that is why we use them to store the data and feed as in when required.

# %%
xph = tf.placeholder(tf.float32,[batch_size])
#traing feature

# %%
yph = tf.placeholder(tf.float32,[batch_size])
#training label

# %%
#operation defined as a graph!
y_model = m * xph + c

# %%
error = tf.reduce_sum(tf.square(yph-y_model))

# %%
optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.001)
train = optimizer.minimize(error)

# %%
initialize_all = tf.global_variables_initializer()

# %%
session = tf.Session()
session.run(initialize_all)

# %%
number_of_batches = 1000
for i in range(number_of_batches):
    
    rand_index = np.random.randint(len(data),size=batch_size)
    
    feed = {xph:data[rand_index],yph:y_exp[rand_index]}
    
    session.run(train,feed_dict=feed)
model_m , model_c = session.run([m,c])

# %%
y_pred = model_m*data + model_c
dataset.sample(300).plot(x='feature',y='Label',kind='scatter')
plt.plot(data,y_pred,'r')

# %%
model_m
# Out:
# 0.45430124

# %%
model_c
# Out:
# 4.989013

# %% [markdown]
# ### Bingo!
